# %% [markdown]
# <a href="https://colab.research.google.com/github/nadavo11/DNN-music-century-prediction/blob/main/assignment1_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 1. Music Century Classification
#
# **Assignment Responsible**: Natalie Lang.
#
# In this assignment, we will build models to predict which
# **century** a piece of music was released.  We will be using the "YearPredictionMSD Data Set"
# based on the Million Song Dataset. The data is available to download from the UCI
# Machine Learning Repository. Here are some links about the data:
#
# - https://archive.ics.uci.edu/ml/datasets/yearpredictionmsd
# - http://millionsongdataset.com/pages/tasks-demos/#yearrecognition
#
# Note that you are note allowed to import additional packages **(especially not PyTorch)**. One of the objectives is to understand how the training procedure actually operates, before working with PyTorch's autograd engine which does it all for us.

# %% [markdown]
# ## Question 1. Data (21%)
#
# Start by setting up a Google Colab notebook in which to do your work.
# Since you are working with a partner, you might find this link helpful:
#
# - https://colab.research.google.com/github/googlecolab/colabtools/blob/master/notebooks/colab-github-demo.ipynb
#
# The recommended way to work together is pair coding, where you and your partner are sitting together and writing code together.
#
# To process and read the data, we use the popular `pandas` package for data analysis.

# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt

class bcolors:
    HEADER = '\033[95m'
    OKBLUE = '\033[94m'
    OKCYAN = '\033[96m'
    OKGREEN = '\033[92m'
    WARNING = '\033[93m'
    FAIL = '\033[91m'
    ENDC = '\033[0m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'

# %% [markdown]
# Now that your notebook is set up, we can load the data into the notebook. The code below provides
# two ways of loading the data: directly from the internet, or through mounting Google Drive.
# The first method is easier but slower, and the second method is a bit involved at first, but
# can save you time later on. You will need to mount Google Drive for later assignments, so we recommend
# figuring how to do that now.
#
# Here are some resources to help you get started:
#
# - http://colab.research.google.com/notebooks/io.ipynb

# %%
load_from_drive = False

if not load_from_drive:
  csv_path = "http://archive.ics.uci.edu/ml/machine-learning-databases/00203/YearPredictionMSD.txt.zip"
else:
  from google.colab import drive
  drive.mount('/content/drive/')
  csv_path = '/content/drive/My Drive/YearPredictionMSD.txt.zip' # TODO - UPDATE ME WITH THE TRUE PATH!

t_label = ["year"]
x_labels = ["var%d" % i for i in range(1, 91)]
df = pandas.read_csv(csv_path, names=t_label + x_labels)

# %% [markdown]
# Now that the data is loaded to your Colab notebook, you should be able to display the Pandas
# DataFrame `df` as a table:

# %%
df
# Out:
#         year      var1      var2      var3      var4      var5      var6  \
# 0       2001  49.94357  21.47114  73.07750   8.74861 -17.40628 -13.09905
# 1       2001  48.73215  18.42930  70.32679  12.94636 -10.32437 -24.83777
# 2       2001  50.95714  31.85602  55.81851  13.41693  -6.57898 -18.54940
# 3       2001  48.24750  -1.89837  36.29772   2.58776   0.97170 -26.21683
# 4       2001  50.97020  42.20998  67.09964   8.46791 -15.85279 -16.81409
# ...      ...       ...       ...       ...       ...       ...       ...
# 515340  2006  51.28467  45.88068  22.19582  -5.53319  -3.61835 -16.36914
# 515341  2006  49.87870  37.93125  18.65987  -3.63581 -27.75665 -18.52988
# 515342  2006  45.12852  12.65758 -38.72018   8.80882 -29.29985  -2.28706
# 515343  2006  44.16614  32.38368  -3.34971  -2.49165 -19.59278 -18.67098
# 515344  2005  51.85726  59.11655  26.39436  -5.46030 -20.69012 -19.95528
#
#             var7      var8      var9  ...     var81      var82      var83  \
# 0      -25.01202 -12.23257   7.83089  ...  13.01620  -54.40548   58.99367
# 1        8.76630  -0.92019  18.76548  ...   5.66812  -19.68073   33.04964
# 2       -3.27872  -2.35035  16.07017  ...   3.03800   26.05866  -50.92779
# 3        5.05097 -10.34124   3.55005  ...  34.57337 -171.70734  -16.96705
# 4      -12.48207  -9.37636  12.63699  ...   9.92661  -55.95724   64.92712
# ...          ...       ...       ...  ...       ...        ...        ...
# 515340   2.12652   5.18160  -8.66890  ...   4.81440   -3.75991  -30.92584
# 515341   7.76108   3.56109  -2.50351  ...  32.38589  -32.75535  -61.05473
# 515342 -18.40424 -22.28726  -4.52429  ... -18.73598  -71.15954 -123.98443
# 515343   8.78428   4.02039 -12.01230  ...  67.16763  282.77624   -4.63677
# 515344  -6.72771   2.29590  10.31018  ... -11.50511  -69.18291   60.58456
#
#             var84     var85     var86      var87     var88      var89  \
# 0        15.37344   1.11144 -23.08793   68.40795  -1.82223  -27.46348
# 1        42.87836  -9.90378 -32.22788   70.49388  12.04941   58.43453
# 2        10.93792  -0.07568  43.20130 -115.00698  -0.05859   39.67068
# 3       -46.67617 -12.51516  82.58061  -72.08993   9.90558  199.62971
# 4       -17.72522  -1.49237  -7.50035   51.76631   7.88713   55.66926
# ...           ...       ...       ...        ...       ...        ...
# 515340   26.33968  -5.03390  21.86037 -142.29410   3.42901  -41.14721
# 515341   56.65182  15.29965  95.88193  -10.63242  12.96552   92.11633
# 515342  121.26989  10.89629  34.62409 -248.61020  -6.07171   53.96319
# 515343  144.00125  21.62652 -29.72432   71.47198  20.32240   14.83107
# 515344   28.64599  -4.39620 -64.56491  -45.61012  -5.51512   32.35602
#
#            var90
# 0        2.26327
# 1       26.92061
# 2       -0.66345
# 3       18.85382
# 4       28.74903
# ...          ...
# 515340 -15.46052
# 515341  10.88815
# 515342  -8.09364
# 515343  39.74909
# 515344  12.17352
#
# [515345 rows x 91 columns]

# %% [markdown]
# To set up our data for classification, we'll use the "year" field to represent
# whether a song was released in the 20-th century. In our case `df["year"]` will be 1 if
# the year was released after 2000, and 0 otherwise.

# %%
#change t to binary value
df["year"] = df["year"].map(lambda x: int(x > 2000))

# %%
df.head(20)
# Out:
#     year      var1       var2      var3      var4      var5      var6  \
# 0      1  49.94357   21.47114  73.07750   8.74861 -17.40628 -13.09905
# 1      1  48.73215   18.42930  70.32679  12.94636 -10.32437 -24.83777
# 2      1  50.95714   31.85602  55.81851  13.41693  -6.57898 -18.54940
# 3      1  48.24750   -1.89837  36.29772   2.58776   0.97170 -26.21683
# 4      1  50.97020   42.20998  67.09964   8.46791 -15.85279 -16.81409
# 5      1  50.54767    0.31568  92.35066  22.38696 -25.51870 -19.04928
# 6      1  50.57546   33.17843  50.53517  11.55217 -27.24764  -8.78206
# 7      1  48.26892    8.97526  75.23158  24.04945 -16.02105 -14.09491
# 8      1  49.75468   33.99581  56.73846   2.89581  -2.92429 -26.44413
# 9      1  45.17809   46.34234 -40.65357  -2.47909   1.21253  -0.65302
# 10     1  39.13076  -23.01763 -36.20583   1.67519  -4.27101  13.01158
# 11     1  37.66498  -34.05910 -17.36060 -26.77781 -39.95119 -20.75000
# 12     1  26.51957 -148.15762 -13.30095  -7.25851  17.22029 -21.99439
# 13     1  37.68491  -26.84185 -27.10566 -14.95883  -5.87200 -21.68979
# 14     0  39.11695   -8.29767 -51.37966  -4.42668 -30.06506 -11.95916
# 15     1  35.05129  -67.97714 -14.20239  -6.68696  -0.61230 -18.70341
# 16     1  33.63129  -96.14912 -89.38216 -12.11699  13.77252  -6.69377
# 17     0  41.38639  -20.78665  51.80155  17.21415 -36.44189 -11.53169
# 18     0  37.45034   11.42615  56.28982  19.58426 -16.43530   2.22457
# 19     0  39.71092   -4.92800  12.88590 -11.87773   2.48031 -16.11028
#
#         var7      var8      var9  ...     var81      var82      var83  \
# 0  -25.01202 -12.23257   7.83089  ...  13.01620  -54.40548   58.99367
# 1    8.76630  -0.92019  18.76548  ...   5.66812  -19.68073   33.04964
# 2   -3.27872  -2.35035  16.07017  ...   3.03800   26.05866  -50.92779
# 3    5.05097 -10.34124   3.55005  ...  34.57337 -171.70734  -16.96705
# 4  -12.48207  -9.37636  12.63699  ...   9.92661  -55.95724   64.92712
# 5   20.67345  -5.19943   3.63566  ...   6.59753  -50.69577   26.02574
# 6  -12.04282  -9.53930  28.61811  ...  11.63681   25.44182  134.62382
# 7    8.11871  -1.87566   7.46701  ...  18.03989  -58.46192  -65.56438
# 8    1.71392  -0.55644  22.08594  ...  18.70812    5.20391  -27.75192
# 9   -6.95536 -12.20040  17.02512  ...  -4.36742  -87.55285  -70.79677
# 10   8.05718  -8.41088   6.27370  ...  32.86051  -26.08461 -186.82429
# 11  -0.10231  -0.89972  -1.30205  ...  11.18909   45.20614   53.83925
# 12   5.51947   3.48418   2.61738  ...  23.80442  251.76360   18.81642
# 13   4.87374 -18.01800   1.52141  ... -67.57637  234.27192  -72.34557
# 14  -0.85322  -8.86179  11.36680  ...  42.22923  478.26580  -10.33823
# 15  -1.31928  -9.46370   5.53492  ...  10.25585   94.90539   15.95689
# 16 -33.36843 -24.81437  21.22757  ...  49.93249  -14.47489   40.70590
# 17  11.75252  -7.62428  -3.65488  ...  50.37614  -40.48205   48.07805
# 18   1.02668  -7.34736  -0.01184  ... -22.46207  -25.77228 -322.42841
# 19 -16.40421  -8.29657   9.86817  ...  11.92816  -73.72412   16.19039
#
#         var84     var85      var86      var87     var88       var89     var90
# 0    15.37344   1.11144  -23.08793   68.40795  -1.82223   -27.46348   2.26327
# 1    42.87836  -9.90378  -32.22788   70.49388  12.04941    58.43453  26.92061
# 2    10.93792  -0.07568   43.20130 -115.00698  -0.05859    39.67068  -0.66345
# 3   -46.67617 -12.51516   82.58061  -72.08993   9.90558   199.62971  18.85382
# 4   -17.72522  -1.49237   -7.50035   51.76631   7.88713    55.66926  28.74903
# 5    18.94430  -0.33730    6.09352   35.18381   5.00283   -11.02257   0.02263
# 6    21.51982   8.17570   35.46251   11.57736   4.50056    -4.62739   1.40192
# 7    46.99856  -4.09602   56.37650  -18.29975  -0.30633     3.98364  -3.72556
# 8    17.22100  -0.85210  -15.67150  -26.36257   5.48708    -9.13495   6.08680
# 9    76.57355  -7.71727    3.26926 -298.49845  11.49326   -89.21804 -15.09719
# 10  113.58176   9.28727   44.60282  158.00425  -2.59543   109.19723  23.36143
# 11    2.59467  -4.00958  -47.74886 -170.92864  -5.19009     8.83617  -7.16056
# 12  157.09656 -27.79449 -137.72740  115.28414  23.00230  -164.02536  51.54138
# 13 -362.25101 -25.55019  -89.08971 -891.58937  14.11648 -1030.99180  99.28967
# 14 -103.76858  39.19511  -98.76636 -122.81061  -2.14942  -211.48202 -12.81569
# 15  -98.15732  -9.64859  -93.52834  -95.82981  20.73063  -562.07671  43.44696
# 16   58.63692   8.81522   27.28474    5.78046   3.44539   259.10825  10.28525
# 17   -7.62399   6.51934  -30.46090  -53.87264   4.44627    58.16913  -0.02409
# 18 -146.57408  13.61588   92.22918 -439.80259  25.73235   157.22967  38.70617
# 19    9.79606   9.71693   -9.90907  -20.65851   2.34002   -31.57015   1.58400
#
# [20 rows x 91 columns]

# %% [markdown]
# ### Part (a) -- 7%
#
# The data set description text asks us to respect the below train/test split to
# avoid the "producer effect". That is, we want to make sure that no song from a single artist
# ends up in both the training and test set.
#
# Explain why it would be problematic to have
# some songs from an artist in the training set, and other songs from the same artist in the
# test set. (Hint: Remember that we want our test accuracy to predict how well the model
# will perform in practice on a song it hasn't learned about.)
#  it would be problematic to have some songs from an artist in the training set, and other songs from the same artist in the test set

# %% [markdown]
# ###Answer
# it would seemingly improuve the performance of the model, due to increased accuracy on these specific artists, while in practice the model wouldn't be as good at classifying completely new data. the results of the test would not reflect the actual accuracy of the model. furtermore memorization of specific parameters is not the goal of our model, rather classifiyng by detecting more complex patterns.

# %%
#devide to train /test sets
df_train = df[:463715]
df_test = df[463715:]

# convert to numpy
train_xs = df_train[x_labels].to_numpy()
train_ts = df_train[t_label].to_numpy()
test_xs = df_test[x_labels].to_numpy()
test_ts = df_test[t_label].to_numpy()

# Write your explanation here

"""it would seemingly improve the performance of the model due to increased accuracy on these specific artists, 
while in practice the modle wouldn't be as good at classifying completely new data. 
the results of the test would not reflect the actual accuracy of the model. 
furtermore memorization of specific parameters is not the goal of our model, rather classifiyng by detecting more complex patterns."""
# Out:
# "it would seemingly improve the performance of the model due to increased accuracy on these specific artists, \nwhile in practice the modle wouldn't be as good at classifying completely new data. \nthe results of the test would not reflect the actual accuracy of the model. \nfurtermore memorization of specific parameters is not the goal of our model, rather classifiyng by detecting more complex patterns."

# %% [markdown]
# ### Part (b) -- 7%
#
# It can be beneficial to **normalize** the columns, so that each column (feature)
# has the *same* mean and standard deviation.

# %%
feature_means = df_train.mean()[1:].to_numpy() # the [1:] removes the mean of the "year" field
feature_stds  = df_train.std()[1:].to_numpy()

train_norm_xs = (train_xs - feature_means) / feature_stds
test_norm_xs = (test_xs - feature_means) / feature_stds

# %% [markdown]
# Notice how in our code, we normalized the test set using the *training data means and standard deviations*.
# This is *not* a bug.
#
# Explain why it would be improper to compute and use test set means
# and standard deviations. (Hint: Remember what we want to use the test accuracy to measure.)

# %%
# Write your explanation here

"""
It would be improper to compute and use test set means and standard deviations because if the means of the tests set are different
from the means of the training set we will normalize the values of the two sets with different arguments what will cause deviation between the normaliztion of them what will
bring us wrong results because of the discrepancy between the two sets
"""
# Out:
# '\nIt would be improper to compute and use test set means and standard deviations because if the means of the tests set are different\nfrom the means of the training set we will normalize the values of the two sets with different arguments what will cause deviation between the normaliztion of them what will\nbring us wrong results because of the discrepancy between the two sets\n'

# %% [markdown]
# ### Part (c) -- 7%
#
# Finally, we'll move some of the data in our training set into a validation set.
#
# Explain why we should limit how many times we use the test set, and that we should use the validation
# set during the model building process.

# %%
# shuffle the training set
reindex = np.random.permutation(len(train_xs))
train_xs = train_xs[reindex]
train_norm_xs = train_norm_xs[reindex]
train_ts = train_ts[reindex]

# use the first 50000 elements of `train_xs` as the validation set
train_xs, val_xs           = train_xs[50000:], train_xs[:50000]
train_norm_xs, val_norm_xs = train_norm_xs[50000:], train_norm_xs[:50000]
train_ts, val_ts           = train_ts[50000:], train_ts[:50000]

# Write your explanation here

"""
The purpose of the validation set is to check the capabilities of the model to evaluate new data that it hasn’t evaluated before during
unlike test set that we use after the training.
The validation set is good for finding and optimizing the best model to solve the problem.
The separation of the test set is meant to make sure the model isnt overfitting and able to deal with a whole new data set, bringing expected results.
 """
# Out:
# '\nThe purpose of the validation set is to check the capabilities of the model to evaluate new data that it hasn’t evaluated before during\nunlike test set that we use after the training.\nThe validation set is good for finding and optimizing the best model to solve the problem.\nThe separation of the test set is meant to make sure the model isnt overfitting and able to deal with a whole new data set, bringing expected results.\n '

# %% [markdown]
# ## Part 2. Classification (79%)
#
# We will first build a *classification* model to perform decade classification.
# These helper functions are written for you. All other code that you write in this section should be vectorized whenever possible (i.e., avoid unnecessary loops).

# %%
epsilon = 2**(-10)
def sigmoid(z):
  return 1 / (1 + np.exp(-z))
    
def cross_entropy(t, y):
  return -t * np.log2(y + epsilon) - (1 - t) * np.log(1 - y + epsilon)

def cost(y, t):
  return np.mean(cross_entropy(t, y))

def get_accuracy(y, t):
  acc = 0
  N = len(y)

  for i in range(N):   
    if (y[i] >= 0.5 and t[i] == 1) or (y[i] < 0.5 and t[i] == 0):
      acc += 1
  return acc / N

# %% [markdown]
# ### Part (a) -- 7%
#
# Write a function `pred` that computes the prediction `y` based on logistic regression, i.e., a single layer with weights `w` and bias `b`. The output is given by:
# \begin{equation}
# y = \sigma({\bf w}^T {\bf x} + b),
# \end{equation}
# where the value of $y$ is an estimate of the probability that the song is released in the current century, namely ${\rm year} =1$.

# %%
def pred(w, b, X):
  """
  Returns the prediction `y` of the target based on the weights `w` and scalar bias `b`.

  Preconditions: np.shape(w) == (90,)
                 type(b) == float
                 np.shape(X) = (N, 90) for some N

  >>> pred(np.zeros(90), 1, np.ones([2, 90]))
  array([0.73105858, 0.73105858]) # It's okay if your output differs in the last decimals
  """
  # Your code goes here
  return sigmoid(np.dot(w,X.T)+b)  # [1..N]

# %% [markdown]
# ### Part (b) -- 7%
#
# Write a function `derivative_cost` that computes and returns the gradients
# $\frac{\partial\mathcal{L}}{\partial {\bf w}}$ and
# $\frac{\partial\mathcal{L}}{\partial b}$. Here, `X` is the input, `y` is the prediction, and `t` is the true label.
#
# first lets explicitly express ${\mathcal{L}}$ :
#
# * N is the batch size.
#
# * i is the index inside the batch.
#
# * j is the index of the variable inside x,${\mathcal{ω}}$.
#
# * X is a matrix of N batches with 90 variables.
#
# ${\mathcal{L} =-\frac{1}{N}\cdot{\sum_{i=1}^{N}} t_i\cdot log(y_i)+(1-t_i)\cdot log(1-y_i)} $
#
#
# $(1) $ Lets calculate $\frac{\partial \mathcal{L}}{\partial \omega}$:
#
# $(a) \frac{\partial\mathcal{L}}{\partial {\ y_i}} = -\frac{1}{N}\cdot\frac{1-t_i}{1-y_i} - \frac{t_i}{y_i} = -\frac{1}{N}\cdot\frac{y(1-t_i)-t(1-y_i)}{y_i(1-y_i)} $
#
# $=-\frac{1}{N}\cdot\frac{y-t_i}{y_i(1-y_i)}$
#
# $(b) \frac{\partial\mathcal{y_i}}{\partial {\omega_j}} = \frac{\partial\mathcal{σ(W^T\cdot X + b)}}{\partial {\omega_j}} = \frac{1}{N}\cdot y_i \cdot (1-y_i)\cdot x_i,_j  \\  $
#
# $(c) \frac{\partial \mathcal{L}}{\partial \omega_j}=\frac{\partial\mathcal{L}}{\partial {\mathcal{y}}}\cdot \frac{\partial\mathcal{y}}{\partial {\omega_j}} = \frac{1}{N}\cdot X_j \cdot (Y-T) \\   $
#
#
#
# $(2) $ Lets calculate $\frac{\partial \mathcal{L}}{\partial \mathcal{b}}$:
#
# $(a) \frac{\partial y}{\partial b} = y \cdot (1-y)$
#
# $(b)\frac{\partial \mathcal{L}}{\partial b} = \frac{\partial \mathcal{L}}{\partial y} \frac{\partial y}{\partial b} = \frac{1}{\mathcal{N}}\sum_{i=1}^N{\mathcal{y_i}} \cdot (1-y_i)  \cdot \frac{y_i-t_i}{(1-y_i)y_i} =\frac{1}{\mathcal{N}}\sum_{i=1}^N (y_i-t_i) $

# %%
def derivative_cost(X, y, t):
  """
  Returns a tuple containing the gradients dLdw and dLdb.

  Precondition: np.shape(X) == (N, 90) for some N
                np.shape(y) == (N,)
                np.shape(t) == (N,)

  Postcondition: np.shape(dLdw) = (90,)
           type(dLdb) = float
  """
  
  # r <- (y - t)
  N = len(y)
  
  y = np.array([y]).reshape((N,1))
  t = np.array([t]).reshape((N,1))

  r = y-t # r [1..N]

      # calculate gradients:
  
  #grad_w = dl/dw   
  Derivative_by_w = np.mean(r*X,axis=0)   #d/dw: [1..90]
  #grad_b = dl/db
  Derivative_by_b = np.mean(r)   ##d/db: scalar

  return Derivative_by_w, Derivative_by_b

# %% [markdown]
# # **Explenation on Gradients**

# %% [markdown]
# **Add here an explaination on how the gradients are computed**:
#
# Write your explanation here. Use Latex to write mathematical expressions. [Here is a brief tutorial on latex for notebooks.](https://www.math.ubc.ca/~pwalls/math-python/jupyter/latex/)

# %% [markdown]
# ## Part (c)✅ -- 7%
#
# ---
#
#
#
# We can check that our derivative is implemented correctly using the finite difference rule. In 1D, the
# finite difference rule tells us that for small $h$, we should have
#
# $$\frac{f(x+h) - f(x)}{h} \approx f'(x)$$
#
# Show that $\frac{\partial\mathcal{L}}{\partial b}$  is implement correctly
# by comparing the result from `derivative_cost` with the empirical cost derivative computed using the above numerical approximation.

# %%
print(train_ts)
# Out:
# [[1]
#  [1]
#  [0]
#  ...
#  [1]
#  [1]
#  [0]]

# %%
from os import XATTR_CREATE
# Your code goes here
h=2**(-10)
# random wheights & biases
w = np.random.randn(90)
b = np.random.randn(1)[0]

#inputs & outputs
X = train_norm_xs[0:50]
t = train_ts[0:50]
y = pred(w,b,X)

y_plus_h = pred(w,b+h,X)

r1 = (cost(y_plus_h,t) - cost(y,t)) / h
r2 = derivative_cost(X,y,t)[1] # 2nd index is dL/db
print("The analytical results is -", r1)
print("The algorithm results is - ", r2)
print("The difference between results is - ", r2-r1)

print("grad shape is:",derivative_cost(X,y,t)[0].shape)
# Out:
# The analytical results is - -0.07658410299154639
# The algorithm results is -  -0.041684566041609354
# The difference between results is -  0.034899536949937034
# grad shape is: (90,)

# %% [markdown]
# ## Part (d) -- 7% ✅
#
# Show that $\frac{\partial\mathcal{L}}{\partial {\bf w}}$  is implement correctly.

# %%
#inputs & outputs
#X = train_norm_xs[0]
#t = train_ts[0]
#y = pred(w,b,X)
N= len(w)
H = np.identity(N)*h


y_plus_h = np.array([pred(w+H[i],b,X) for i in range(N)])

cost_y_plus_h = np.array([cost(y_plus_h[i],t) for i in range(N)])

r1 = (cost_y_plus_h - cost(y,t)) / h
r2 = derivative_cost(X,y,t)[0] # 1st index is dL/db
MSE = np.mean([(r1-r2)**2])
print("The analytical results is -", r1,'\n')
print("The algorithm results is - ", r2,'\n')
print("MSE is ", MSE,'\n')
# Out:
# The analytical results is - [ 0.10555612  0.05881361  0.06562533 -0.08765348  0.03515633 -0.08390544
#  -0.07932533 -0.02361659  0.00515006  0.07304897  0.00741272  0.07386217
#  -0.10728487 -0.12394815 -0.08943321 -0.07408369 -0.04978669 -0.12315455
#  -0.00596367 -0.09656477  0.0080071  -0.08141415 -0.07279601  0.02515888
#  -0.06267471 -0.07433615  0.00690213  0.02603519 -0.06711898 -0.01697508
#   0.01480863 -0.03985735  0.05822892  0.01833982  0.05637111 -0.04873552
#  -0.04988463  0.0610817  -0.08962205 -0.03898496 -0.20039281 -0.03302871
#  -0.0635091  -0.0849703  -0.03137945 -0.00881448 -0.07794212 -0.04837903
#   0.02049981  0.02142564 -0.03051262 -0.01412346  0.02657693 -0.04450616
#   0.0519006  -0.09067595 -0.03489605 -0.00029751  0.01655055  0.0679782
#  -0.04226229  0.03228786 -0.1122895   0.03706923 -0.03544576  0.0234253
#   0.11516786 -0.05996159  0.00048355  0.01069771 -0.03359535  0.07399545
#  -0.05592421 -0.03357969  0.08473211 -0.06242722 -0.00397565  0.04383487
#  -0.04002459 -0.08638002 -0.01212898  0.06829856  0.01331323  0.07679513
#   0.15697426  0.01549015  0.05669189 -0.04163253  0.0944656   0.04683497]
#
# The algorithm results is -  [ 0.03327377  0.07622139  0.00653798 -0.01806008  0.03949469  0.04186501
#  -0.04910741 -0.02417794 -0.03990097  0.02911583  0.00654514  0.11566271
#  -0.08550722 -0.30933923 -0.16244784 -0.08855073 -0.12115881 -0.04006754
#  -0.07090524 -0.12214273 -0.12265805 -0.0946092  -0.08933475 -0.04827598
#   0.03123853 -0.24900462 -0.01368125 -0.11044936 -0.01416175  0.03223464
#   0.10349317 -0.16058295 -0.13337314 -0.02332155  0.08400324 -0.01438995
#  -0.18847924 -0.00114166 -0.08554183  0.02842496 -0.03610134  0.0895359
#  -0.15793776  0.04090648  0.13034039  0.07299554 -0.10736198 -0.13379223
#   0.06583259  0.04216765  0.18781768 -0.00057249  0.0340069  -0.02146663
#   0.05648732 -0.2387501  -0.03148111 -0.02653482 -0.03195152  0.01451749
#  -0.10671783  0.0648067   0.01253233 -0.09640748  0.02333833  0.23703674
#   0.00272908 -0.09374314 -0.08128757 -0.01259058  0.00877104  0.15468146
#  -0.01547067 -0.04935737  0.16875872 -0.09495615  0.33078207 -0.03712615
#   0.10264391 -0.1537976  -0.09593663  0.2192536  -0.07223079  0.17744807
#   0.0056246   0.09118558 -0.02724099  0.04736777  0.01484962  0.06339334]
#
# MSE is  0.009168177915617332

# %% [markdown]
# ## Part (e)✅ -- 7%
#
# Now that you have a gradient function that works, we can actually run gradient descent.
# Complete the following code that will run stochastic: gradient descent training:

# %%
def run_gradient_descent(train_norm_xs,train_ts,w0, b0, mu=0.1, batch_size=100, max_iters=100):
  """Return the values of (w, b) after running gradient descent for max_iters.
  We use:
    - train_norm_xs and train_ts as the training set
    - val_norm_xs and val_ts as the test set
    - mu as the learning rate
    - (w0, b0) as the initial values of (w, b)

  Precondition: np.shape(w0) == (90,)
                type(b0) == float
 
  Postcondition: np.shape(w) == (90,)
                 type(b) == float
  """
  w = w0
  b = b0
  iter = 0
  while iter < max_iters:
      
    # shuffle the training set (there is code above for how to do this)
    reindex = np.random.permutation(len(train_norm_xs))
    train_norm_xs = train_norm_xs[reindex]
    train_ts = train_ts[reindex]
      
    val_acc_history =[]
    val_cost_history = []
    for i in range(0, len(train_norm_xs), batch_size): # iterate over each minibatch
        
      
      # minibatch that we are working with:
      X = train_norm_xs[i:(i + batch_size)]
      t = train_ts[i:(i + batch_size), 0]
      

      # since len(train_norm_xs) does not divide batch_size evenly, we will skip over
      # the "last" minibatch
      if np.shape(X)[0] != batch_size:
        continue

      # compute the prediction
      y = pred(w,b,X)

      # update w and b
      gradient = derivative_cost(X,y,t)
      
        
      # increment the iteration count
      
      # compute and print the *validation* loss and accuracy 
      # CLARIFICATION: we will only compute fo a batch sized subset, beacause of computation limitations
      # on cloud platform
      if (iter % 10 == 0):
        print(iter) 
        val_pred = pred(w,b,val_norm_xs[:10*batch_size])
        val_cost = cost(val_pred , val_ts[:10*batch_size])
        val_acc = get_accuracy(val_pred,val_ts[:10*batch_size])
        
        #record acc values{}
        val_acc_history.append(val_acc)
        val_cost_history.append(val_cost)
        print("Iter %d. [Val Acc %.0f%%, Loss %f]" % (
                iter, val_acc * 100, val_cost))
      iter += 1
      w -= mu*gradient[0]
      b -= mu*gradient[1]
      if iter >= max_iters:
        break

      # Think what parameters you should return for further use

    model = (w,b)
    
  return model, val_acc_history, val_cost_history

# %% [markdown]
# ### Part (f) -- 7%
#
# Call `run_gradient_descent` with the weights and biases all initialized to zero.
# Show that if the learning rate $\mu$ is too small, then convergence is slow.
# Also, show that if $\mu$ is too large, then the optimization algorirthm does not converge. The demonstration should be made using plots showing these effects.

# %%
w0 = np.random.randn(90)
b0 = np.random.randn(1)[0]

w0 *= 0
b0 *= 0

batch_size = 100
max_iters = 600

low_mu = 2**(-10)
high_mu = 2

model , history_acc_low_mu , history_cost_low_mu = run_gradient_descent(train_norm_xs,train_ts,w0,b0,low_mu,batch_size=batch_size,max_iters=max_iters)
model , history_acc_high_mu , history_cost_high_mu = run_gradient_descent(train_norm_xs,train_ts,w0,b0,high_mu,batch_size=batch_size,max_iters=max_iters)
# Out:
# 0
# Iter 0. [Val Acc 58%, Loss 0.869894]
# 10
# Iter 10. [Val Acc 66%, Loss 0.869828]
# 20
# Iter 20. [Val Acc 64%, Loss 0.869668]
# 30
# Iter 30. [Val Acc 64%, Loss 0.869634]
# 40
# Iter 40. [Val Acc 65%, Loss 0.869522]
# 50
# Iter 50. [Val Acc 66%, Loss 0.869497]
# 60
# Iter 60. [Val Acc 65%, Loss 0.869387]
# 70
# Iter 70. [Val Acc 66%, Loss 0.869312]
# 80
# Iter 80. [Val Acc 66%, Loss 0.869252]
# 90
# Iter 90. [Val Acc 66%, Loss 0.869200]
# 100
# Iter 100. [Val Acc 66%, Loss 0.869133]
# 110
# Iter 110. [Val Acc 66%, Loss 0.869084]
# 120
# Iter 120. [Val Acc 66%, Loss 0.868977]
# 130
# Iter 130. [Val Acc 66%, Loss 0.868914]
# 140
# Iter 140. [Val Acc 66%, Loss 0.868881]
# 150
# Iter 150. [Val Acc 66%, Loss 0.868818]
# 160
# Iter 160. [Val Acc 66%, Loss 0.868772]
# 170
# Iter 170. [Val Acc 67%, Loss 0.868819]
# 180
# Iter 180. [Val Acc 66%, Loss 0.868824]
# 190
# Iter 190. [Val Acc 66%, Loss 0.868682]
# 200
# Iter 200. [Val Acc 66%, Loss 0.868703]
# 210
# Iter 210. [Val Acc 66%, Loss 0.868705]
# 220
# Iter 220. [Val Acc 67%, Loss 0.868627]
# 230
# Iter 230. [Val Acc 67%, Loss 0.868544]
# 240
# Iter 240. [Val Acc 67%, Loss 0.868592]
# 250
# Iter 250. [Val Acc 67%, Loss 0.868586]
# 260
# Iter 260. [Val Acc 66%, Loss 0.868562]
# 270
# Iter 270. [Val Acc 67%, Loss 0.868551]
# 280
# Iter 280. [Val Acc 67%, Loss 0.868554]
# 290
# Iter 290. [Val Acc 67%, Loss 0.868605]
# 300
# Iter 300. [Val Acc 67%, Loss 0.868686]
# 310
# Iter 310. [Val Acc 66%, Loss 0.868696]
# 320
# Iter 320. [Val Acc 67%, Loss 0.868747]
# 330
# Iter 330. [Val Acc 67%, Loss 0.868784]
# 340
# Iter 340. [Val Acc 67%, Loss 0.868811]
# 350
# Iter 350. [Val Acc 66%, Loss 0.868744]
# 360
# Iter 360. [Val Acc 66%, Loss 0.868722]
# 370
# Iter 370. [Val Acc 66%, Loss 0.868693]
# 380
# Iter 380. [Val Acc 66%, Loss 0.868790]
# 390
# Iter 390. [Val Acc 66%, Loss 0.868846]
# 400
# Iter 400. [Val Acc 66%, Loss 0.868753]
# 410
# Iter 410. [Val Acc 66%, Loss 0.868785]
# 420
# Iter 420. [Val Acc 67%, Loss 0.868839]
# 430
# Iter 430. [Val Acc 67%, Loss 0.868837]
# 440
# Iter 440. [Val Acc 67%, Loss 0.868883]
# 450
# Iter 450. [Val Acc 67%, Loss 0.868952]
# 460
# Iter 460. [Val Acc 67%, Loss 0.868882]
# 470
# Iter 470. [Val Acc 67%, Loss 0.868879]
# 480
# Iter 480. [Val Acc 67%, Loss 0.868927]
# 490
# Iter 490. [Val Acc 67%, Loss 0.868976]
# 500
# Iter 500. [Val Acc 67%, Loss 0.868981]
# 510
# Iter 510. [Val Acc 67%, Loss 0.869015]
# 520
# Iter 520. [Val Acc 67%, Loss 0.869113]
# 530
# Iter 530. [Val Acc 67%, Loss 0.869116]
# 540
# Iter 540. [Val Acc 67%, Loss 0.869202]
# 550
# Iter 550. [Val Acc 67%, Loss 0.869200]
# 560
# Iter 560. [Val Acc 68%, Loss 0.869212]
# 570
# Iter 570. [Val Acc 67%, Loss 0.869238]
# 580
# Iter 580. [Val Acc 67%, Loss 0.869280]
# 590
# Iter 590. [Val Acc 67%, Loss 0.869282]
# 0
# Iter 0. [Val Acc 67%, Loss 0.876348]
# 10
# Iter 10. [Val Acc 62%, Loss 1.381295]
# 20
# Iter 20. [Val Acc 62%, Loss 1.624056]
# 30
# Iter 30. [Val Acc 68%, Loss 1.371897]
# 40
# Iter 40. [Val Acc 65%, Loss 1.483358]
# 50
# Iter 50. [Val Acc 64%, Loss 1.668701]
# 60
# Iter 60. [Val Acc 68%, Loss 1.376661]
# 70
# Iter 70. [Val Acc 65%, Loss 1.655063]
# 80
# Iter 80. [Val Acc 70%, Loss 1.469864]
# 90
# Iter 90. [Val Acc 71%, Loss 1.397558]
# 100
# Iter 100. [Val Acc 58%, Loss 1.730325]
# 110
# Iter 110. [Val Acc 71%, Loss 1.428475]
# 120
# Iter 120. [Val Acc 64%, Loss 1.899411]
# 130
# Iter 130. [Val Acc 62%, Loss 1.755791]
# 140
# Iter 140. [Val Acc 72%, Loss 1.416796]
# 150
# Iter 150. [Val Acc 68%, Loss 1.523181]
# 160
# Iter 160. [Val Acc 71%, Loss 1.411979]
# 170
# Iter 170. [Val Acc 66%, Loss 1.762194]
# 180
# Iter 180. [Val Acc 62%, Loss 1.689299]
# 190
# Iter 190. [Val Acc 69%, Loss 1.598942]
# 200
# Iter 200. [Val Acc 67%, Loss 1.525256]
# 210
# Iter 210. [Val Acc 64%, Loss 1.524537]
# 220
# Iter 220. [Val Acc 71%, Loss 1.396467]
# 230
# Iter 230. [Val Acc 71%, Loss 1.398085]
# 240
# Iter 240. [Val Acc 66%, Loss 1.602764]
# 250
# Iter 250. [Val Acc 66%, Loss 1.682857]
# 260
# Iter 260. [Val Acc 72%, Loss 1.414629]
# 270
# Iter 270. [Val Acc 70%, Loss 1.499856]
# 280
# Iter 280. [Val Acc 70%, Loss 1.438258]
# 290
# Iter 290. [Val Acc 65%, Loss 1.426563]
# 300
# Iter 300. [Val Acc 65%, Loss 1.683923]
# 310
# Iter 310. [Val Acc 68%, Loss 1.709702]
# 320
# Iter 320. [Val Acc 71%, Loss 1.467334]
# 330
# Iter 330. [Val Acc 63%, Loss 1.986357]
# 340
# Iter 340. [Val Acc 72%, Loss 1.433999]
# 350
# Iter 350. [Val Acc 73%, Loss 1.471339]
# 360
# Iter 360. [Val Acc 67%, Loss 1.597669]
# 370
# Iter 370. [Val Acc 67%, Loss 1.523605]
# 380
# Iter 380. [Val Acc 67%, Loss 1.539563]
# 390
# Iter 390. [Val Acc 61%, Loss 1.804761]
# 400
# Iter 400. [Val Acc 68%, Loss 1.512951]
# 410
# Iter 410. [Val Acc 67%, Loss 1.468078]
# 420
# Iter 420. [Val Acc 63%, Loss 1.852454]
# 430
# Iter 430. [Val Acc 71%, Loss 1.332650]
# 440
# Iter 440. [Val Acc 69%, Loss 1.399205]
# 450
# Iter 450. [Val Acc 69%, Loss 1.321424]
# 460
# Iter 460. [Val Acc 67%, Loss 1.554779]
# 470
# Iter 470. [Val Acc 70%, Loss 1.506092]
# 480
# Iter 480. [Val Acc 68%, Loss 1.456611]
# 490
# Iter 490. [Val Acc 64%, Loss 1.634348]
# 500
# Iter 500. [Val Acc 66%, Loss 1.813218]
# 510
# Iter 510. [Val Acc 66%, Loss 1.677766]
# 520
# Iter 520. [Val Acc 67%, Loss 1.430024]
# 530
# Iter 530. [Val Acc 66%, Loss 1.515208]
# 540
# Iter 540. [Val Acc 65%, Loss 1.549304]
# 550
# Iter 550. [Val Acc 64%, Loss 1.421964]
# 560
# Iter 560. [Val Acc 67%, Loss 1.704113]
# 570
# Iter 570. [Val Acc 64%, Loss 1.647869]
# 580
# Iter 580. [Val Acc 64%, Loss 1.550335]
# 590
# Iter 590. [Val Acc 65%, Loss 1.814540]

# %% [markdown]
# **Explain and discuss your results here:**
#
# The plots below presents the accuracy and cost curves, with respect to epoch.
# It seems that the curve using a very small $\mu$ converge very slowly, as its values does not reach the final accuracy values presented in the end of the task.
# On the other curve, using a relatively big $\mu$ causes divergence, probably due to overshooting.

# %%
#plot both graphs on the same plot
plt.plot(range(len(history_acc_low_mu)),history_acc_low_mu)
plt.plot(range(len(history_acc_high_mu)),history_acc_high_mu)
plt.title(f'Accuracy vs. Number of epochs')
plt.legend(['Low mu','High mu'])


iters = np.array(range(len(history_cost_low_mu)))

plt.figure(3)
plt.plot(iters,history_cost_low_mu)
plt.title(f'Cost vs. Number of epochs')
plt.plot(iters,history_cost_high_mu)

plt.legend(['Low mu','High mu'])

# %% [markdown]
# ### Part (g) -- 7%
#
# Find the optimial value of ${\bf w}$ and $b$ using your code. Explain how you chose
# the learning rate $\mu$ and the batch size. Show plots demostrating good and bad behaviours.

# %%
#define inital  params
w0 = np.random.randn(90)
b0 = np.random.randn(1)[0]

mu = low_mu
for i in range(1,10):
  mu = mu*2

#train the model
  model, history_acc, history_cost = run_gradient_descent(train_norm_xs,train_ts,w0,b0,mu,batch_size=batch_size,max_iters=max_iters)

#plot learning curve  
  plt.figure(i)
  plt.plot(iters,history_acc)
  plt.title(f'Accuracy vs. Number of epochs, mu = {mu}')
# Out:
# 0
# Iter 0. [Val Acc 52%, Loss 3.138047]
# 10
# Iter 10. [Val Acc 52%, Loss 3.132454]
# 20
# Iter 20. [Val Acc 52%, Loss 3.127394]
# 30
# Iter 30. [Val Acc 52%, Loss 3.121917]
# 40
# Iter 40. [Val Acc 52%, Loss 3.115917]
# 50
# Iter 50. [Val Acc 52%, Loss 3.110334]
# 60
# Iter 60. [Val Acc 52%, Loss 3.105332]
# 70
# Iter 70. [Val Acc 52%, Loss 3.100799]
# 80
# Iter 80. [Val Acc 52%, Loss 3.095290]
# 90
# Iter 90. [Val Acc 52%, Loss 3.090450]
# 100
# Iter 100. [Val Acc 52%, Loss 3.084709]
# 110
# Iter 110. [Val Acc 52%, Loss 3.079610]
# 120
# Iter 120. [Val Acc 52%, Loss 3.074934]
# 130
# Iter 130. [Val Acc 52%, Loss 3.069511]
# 140
# Iter 140. [Val Acc 52%, Loss 3.064036]
# 150
# Iter 150. [Val Acc 52%, Loss 3.058775]
# 160
# Iter 160. [Val Acc 52%, Loss 3.053736]
# 170
# Iter 170. [Val Acc 52%, Loss 3.048158]
# 180
# Iter 180. [Val Acc 52%, Loss 3.041956]
# 190
# Iter 190. [Val Acc 52%, Loss 3.036845]
# 200
# Iter 200. [Val Acc 52%, Loss 3.031051]
# 210
# Iter 210. [Val Acc 52%, Loss 3.024865]
# 220
# Iter 220. [Val Acc 52%, Loss 3.019770]
# 230
# Iter 230. [Val Acc 52%, Loss 3.014440]
# 240
# Iter 240. [Val Acc 52%, Loss 3.009498]
# 250
# Iter 250. [Val Acc 52%, Loss 3.003982]
# 260
# Iter 260. [Val Acc 52%, Loss 2.999353]
# 270
# Iter 270. [Val Acc 52%, Loss 2.994581]
# 280
# Iter 280. [Val Acc 52%, Loss 2.989309]
# 290
# Iter 290. [Val Acc 52%, Loss 2.983553]
# 300
# Iter 300. [Val Acc 52%, Loss 2.978469]
# 310
# Iter 310. [Val Acc 52%, Loss 2.973489]
# 320
# Iter 320. [Val Acc 52%, Loss 2.969005]
# 330
# Iter 330. [Val Acc 52%, Loss 2.964349]
# 340
# Iter 340. [Val Acc 52%, Loss 2.959471]
# 350
# Iter 350. [Val Acc 52%, Loss 2.954920]
# 360
# Iter 360. [Val Acc 52%, Loss 2.950071]
# 370
# Iter 370. [Val Acc 52%, Loss 2.946025]
# 380
# Iter 380. [Val Acc 53%, Loss 2.940942]
# 390
# Iter 390. [Val Acc 53%, Loss 2.936565]
# 400
# Iter 400. [Val Acc 53%, Loss 2.932589]
# 410
# Iter 410. [Val Acc 53%, Loss 2.928483]
# 420
# Iter 420. [Val Acc 53%, Loss 2.923995]
# 430
# Iter 430. [Val Acc 52%, Loss 2.919039]
# 440
# Iter 440. [Val Acc 52%, Loss 2.915691]
# 450
# Iter 450. [Val Acc 53%, Loss 2.911335]
# 460
# Iter 460. [Val Acc 53%, Loss 2.906569]
# 470
# Iter 470. [Val Acc 53%, Loss 2.901795]
# 480
# Iter 480. [Val Acc 53%, Loss 2.896988]
# 490
# Iter 490. [Val Acc 53%, Loss 2.892960]
# 500
# Iter 500. [Val Acc 53%, Loss 2.888834]
# 510
# Iter 510. [Val Acc 53%, Loss 2.884447]
# 520
# Iter 520. [Val Acc 53%, Loss 2.880424]
# 530
# Iter 530. [Val Acc 53%, Loss 2.876867]
# 540
# Iter 540. [Val Acc 53%, Loss 2.872497]
# 550
# Iter 550. [Val Acc 53%, Loss 2.868465]
# 560
# Iter 560. [Val Acc 53%, Loss 2.864465]
# 570
# Iter 570. [Val Acc 53%, Loss 2.860425]
# 580
# Iter 580. [Val Acc 53%, Loss 2.856312]
# 590
# Iter 590. [Val Acc 53%, Loss 2.852137]
# 0
# Iter 0. [Val Acc 53%, Loss 2.881206]
# 10
# Iter 10. [Val Acc 53%, Loss 2.873250]
# 20
# Iter 20. [Val Acc 53%, Loss 2.865010]
# 30
# Iter 30. [Val Acc 53%, Loss 2.858214]
# 40
# Iter 40. [Val Acc 52%, Loss 2.850212]
# 50
# Iter 50. [Val Acc 52%, Loss 2.843331]
# 60
# Iter 60. [Val Acc 53%, Loss 2.836081]
# 70
# Iter 70. [Val Acc 53%, Loss 2.827946]
# 80
# Iter 80. [Val Acc 53%, Loss 2.820987]
# 90
# Iter 90. [Val Acc 52%, Loss 2.813638]
# 100
# Iter 100. [Val Acc 52%, Loss 2.806497]
# 110
# Iter 110. [Val Acc 52%, Loss 2.799646]
# 120
# Iter 120. [Val Acc 53%, Loss 2.793086]
# 130
# Iter 130. [Val Acc 53%, Loss 2.787014]
# 140
# Iter 140. [Val Acc 53%, Loss 2.781489]
# 150
# Iter 150. [Val Acc 53%, Loss 2.775535]
# 160
# Iter 160. [Val Acc 53%, Loss 2.768037]
# 170
# Iter 170. [Val Acc 53%, Loss 2.762210]
# 180
# Iter 180. [Val Acc 53%, Loss 2.756612]
# 190
# Iter 190. [Val Acc 53%, Loss 2.750130]
# 200
# Iter 200. [Val Acc 53%, Loss 2.744326]
# 210
# Iter 210. [Val Acc 53%, Loss 2.737726]
# 220
# Iter 220. [Val Acc 53%, Loss 2.731328]
# 230
# Iter 230. [Val Acc 53%, Loss 2.725755]
# 240
# Iter 240. [Val Acc 53%, Loss 2.719185]
# 250
# Iter 250. [Val Acc 53%, Loss 2.713894]
# 260
# Iter 260. [Val Acc 53%, Loss 2.707711]
# 270
# Iter 270. [Val Acc 53%, Loss 2.702390]
# 280
# Iter 280. [Val Acc 53%, Loss 2.696149]
# 290
# Iter 290. [Val Acc 53%, Loss 2.691314]
# 300
# Iter 300. [Val Acc 54%, Loss 2.685032]
# 310
# Iter 310. [Val Acc 54%, Loss 2.680148]
# 320
# Iter 320. [Val Acc 54%, Loss 2.675231]
# 330
# Iter 330. [Val Acc 54%, Loss 2.669783]
# 340
# Iter 340. [Val Acc 53%, Loss 2.665570]
# 350
# Iter 350. [Val Acc 53%, Loss 2.660139]
# 360
# Iter 360. [Val Acc 53%, Loss 2.654773]
# 370
# Iter 370. [Val Acc 53%, Loss 2.649887]
# 380
# Iter 380. [Val Acc 53%, Loss 2.645740]
# 390
# Iter 390. [Val Acc 53%, Loss 2.641263]
# 400
# Iter 400. [Val Acc 53%, Loss 2.635707]
# 410
# Iter 410. [Val Acc 53%, Loss 2.630934]
# 420
# Iter 420. [Val Acc 53%, Loss 2.625857]
# 430
# Iter 430. [Val Acc 53%, Loss 2.621509]
# 440
# Iter 440. [Val Acc 53%, Loss 2.617751]
# 450
# Iter 450. [Val Acc 53%, Loss 2.612921]
# 460
# Iter 460. [Val Acc 53%, Loss 2.608431]
# 470
# Iter 470. [Val Acc 54%, Loss 2.604664]
# 480
# Iter 480. [Val Acc 54%, Loss 2.600391]
# 490
# Iter 490. [Val Acc 54%, Loss 2.596269]
# 500
# Iter 500. [Val Acc 54%, Loss 2.592710]
# 510
# Iter 510. [Val Acc 54%, Loss 2.588653]
# 520
# Iter 520. [Val Acc 54%, Loss 2.584125]
# 530
# Iter 530. [Val Acc 54%, Loss 2.579658]
# 540
# Iter 540. [Val Acc 54%, Loss 2.575688]
# 550
# Iter 550. [Val Acc 54%, Loss 2.571261]
# 560
# Iter 560. [Val Acc 54%, Loss 2.567568]
# 570
# Iter 570. [Val Acc 54%, Loss 2.563325]
# 580
# Iter 580. [Val Acc 54%, Loss 2.559848]
# 590
# Iter 590. [Val Acc 55%, Loss 2.556086]
# 0
# Iter 0. [Val Acc 54%, Loss 2.602758]
# 10
# Iter 10. [Val Acc 54%, Loss 2.594423]
# 20
# Iter 20. [Val Acc 54%, Loss 2.586330]
# 30
# Iter 30. [Val Acc 54%, Loss 2.578409]
# 40
# Iter 40. [Val Acc 54%, Loss 2.568778]
# 50
# Iter 50. [Val Acc 54%, Loss 2.560274]
# 60
# Iter 60. [Val Acc 54%, Loss 2.552429]
# 70
# Iter 70. [Val Acc 54%, Loss 2.544218]
# 80
# Iter 80. [Val Acc 54%, Loss 2.536374]
# 90
# Iter 90. [Val Acc 54%, Loss 2.529362]
# 100
# Iter 100. [Val Acc 54%, Loss 2.523139]
# 110
# Iter 110. [Val Acc 54%, Loss 2.514722]
# 120
# Iter 120. [Val Acc 54%, Loss 2.507620]
# 130
# Iter 130. [Val Acc 54%, Loss 2.500147]
# 140
# Iter 140. [Val Acc 54%, Loss 2.492525]
# 150
# Iter 150. [Val Acc 55%, Loss 2.485424]
# 160
# Iter 160. [Val Acc 55%, Loss 2.478470]
# 170
# Iter 170. [Val Acc 55%, Loss 2.470753]
# 180
# Iter 180. [Val Acc 55%, Loss 2.463386]
# 190
# Iter 190. [Val Acc 55%, Loss 2.457036]
# 200
# Iter 200. [Val Acc 55%, Loss 2.450322]
# 210
# Iter 210. [Val Acc 55%, Loss 2.444804]
# 220
# Iter 220. [Val Acc 55%, Loss 2.437416]
# 230
# Iter 230. [Val Acc 55%, Loss 2.430422]
# 240
# Iter 240. [Val Acc 55%, Loss 2.424922]
# 250
# Iter 250. [Val Acc 55%, Loss 2.418654]
# 260
# Iter 260. [Val Acc 55%, Loss 2.412058]
# 270
# Iter 270. [Val Acc 56%, Loss 2.405493]
# 280
# Iter 280. [Val Acc 56%, Loss 2.399409]
# 290
# Iter 290. [Val Acc 55%, Loss 2.392665]
# 300
# Iter 300. [Val Acc 55%, Loss 2.387012]
# 310
# Iter 310. [Val Acc 56%, Loss 2.380606]
# 320
# Iter 320. [Val Acc 55%, Loss 2.374428]
# 330
# Iter 330. [Val Acc 56%, Loss 2.368360]
# 340
# Iter 340. [Val Acc 55%, Loss 2.361735]
# 350
# Iter 350. [Val Acc 55%, Loss 2.356044]
# 360
# Iter 360. [Val Acc 55%, Loss 2.349786]
# 370
# Iter 370. [Val Acc 55%, Loss 2.344910]
# 380
# Iter 380. [Val Acc 55%, Loss 2.338239]
# 390
# Iter 390. [Val Acc 56%, Loss 2.333089]
# 400
# Iter 400. [Val Acc 55%, Loss 2.327464]
# 410
# Iter 410. [Val Acc 55%, Loss 2.321541]
# 420
# Iter 420. [Val Acc 56%, Loss 2.316297]
# 430
# Iter 430. [Val Acc 56%, Loss 2.311605]
# 440
# Iter 440. [Val Acc 56%, Loss 2.307061]
# 450
# Iter 450. [Val Acc 56%, Loss 2.301791]
# 460
# Iter 460. [Val Acc 56%, Loss 2.296741]
# 470
# Iter 470. [Val Acc 56%, Loss 2.291226]
# 480
# Iter 480. [Val Acc 56%, Loss 2.286349]
# 490
# Iter 490. [Val Acc 56%, Loss 2.281490]
# 500
# Iter 500. [Val Acc 56%, Loss 2.276681]
# 510
# Iter 510. [Val Acc 56%, Loss 2.270707]
# 520
# Iter 520. [Val Acc 56%, Loss 2.265542]
# 530
# Iter 530. [Val Acc 56%, Loss 2.260419]
# 540
# Iter 540. [Val Acc 56%, Loss 2.255982]
# 550
# Iter 550. [Val Acc 56%, Loss 2.251142]
# 560
# Iter 560. [Val Acc 56%, Loss 2.245022]
# 570
# Iter 570. [Val Acc 56%, Loss 2.239584]
# 580
# Iter 580. [Val Acc 56%, Loss 2.233051]
# 590
# Iter 590. [Val Acc 56%, Loss 2.227905]
# 0
# Iter 0. [Val Acc 56%, Loss 2.309883]
# 10
# Iter 10. [Val Acc 56%, Loss 2.298162]
# 20
# Iter 20. [Val Acc 56%, Loss 2.285458]
# 30
# Iter 30. [Val Acc 56%, Loss 2.272128]
# 40
# Iter 40. [Val Acc 56%, Loss 2.260138]
# 50
# Iter 50. [Val Acc 56%, Loss 2.247548]
# 60
# Iter 60. [Val Acc 56%, Loss 2.234820]
# 70
# Iter 70. [Val Acc 56%, Loss 2.224213]
# 80
# Iter 80. [Val Acc 57%, Loss 2.213409]
# 90
# Iter 90. [Val Acc 57%, Loss 2.202598]
# 100
# Iter 100. [Val Acc 57%, Loss 2.191048]
# 110
# Iter 110. [Val Acc 57%, Loss 2.180703]
# 120
# Iter 120. [Val Acc 57%, Loss 2.170549]
# 130
# Iter 130. [Val Acc 58%, Loss 2.159675]
# 140
# Iter 140. [Val Acc 58%, Loss 2.152150]
# 150
# Iter 150. [Val Acc 58%, Loss 2.140748]
# 160
# Iter 160. [Val Acc 58%, Loss 2.132007]
# 170
# Iter 170. [Val Acc 58%, Loss 2.121332]
# 180
# Iter 180. [Val Acc 59%, Loss 2.111420]
# 190
# Iter 190. [Val Acc 59%, Loss 2.102640]
# 200
# Iter 200. [Val Acc 59%, Loss 2.092601]
# 210
# Iter 210. [Val Acc 59%, Loss 2.080894]
# 220
# Iter 220. [Val Acc 59%, Loss 2.070909]
# 230
# Iter 230. [Val Acc 59%, Loss 2.062422]
# 240
# Iter 240. [Val Acc 59%, Loss 2.054348]
# 250
# Iter 250. [Val Acc 59%, Loss 2.046064]
# 260
# Iter 260. [Val Acc 60%, Loss 2.035728]
# 270
# Iter 270. [Val Acc 60%, Loss 2.027622]
# 280
# Iter 280. [Val Acc 60%, Loss 2.017114]
# 290
# Iter 290. [Val Acc 60%, Loss 2.007812]
# 300
# Iter 300. [Val Acc 60%, Loss 1.998683]
# 310
# Iter 310. [Val Acc 60%, Loss 1.989606]
# 320
# Iter 320. [Val Acc 60%, Loss 1.979675]
# 330
# Iter 330. [Val Acc 60%, Loss 1.969966]
# 340
# Iter 340. [Val Acc 60%, Loss 1.961744]
# 350
# Iter 350. [Val Acc 61%, Loss 1.953441]
# 360
# Iter 360. [Val Acc 60%, Loss 1.944222]
# 370
# Iter 370. [Val Acc 60%, Loss 1.934801]
# 380
# Iter 380. [Val Acc 60%, Loss 1.927023]
# 390
# Iter 390. [Val Acc 61%, Loss 1.918305]
# 400
# Iter 400. [Val Acc 61%, Loss 1.910758]
# 410
# Iter 410. [Val Acc 61%, Loss 1.902377]
# 420
# Iter 420. [Val Acc 61%, Loss 1.894251]
# 430
# Iter 430. [Val Acc 61%, Loss 1.887389]
# 440
# Iter 440. [Val Acc 61%, Loss 1.880473]
# 450
# Iter 450. [Val Acc 61%, Loss 1.871998]
# 460
# Iter 460. [Val Acc 61%, Loss 1.862070]
# 470
# Iter 470. [Val Acc 61%, Loss 1.856172]
# 480
# Iter 480. [Val Acc 61%, Loss 1.847439]
# 490
# Iter 490. [Val Acc 61%, Loss 1.839561]
# 500
# Iter 500. [Val Acc 61%, Loss 1.831893]
# 510
# Iter 510. [Val Acc 61%, Loss 1.825637]
# 520
# Iter 520. [Val Acc 62%, Loss 1.815769]
# 530
# Iter 530. [Val Acc 61%, Loss 1.807828]
# 540
# Iter 540. [Val Acc 61%, Loss 1.799599]
# 550
# Iter 550. [Val Acc 61%, Loss 1.791758]
# 560
# Iter 560. [Val Acc 61%, Loss 1.785023]
# 570
# Iter 570. [Val Acc 62%, Loss 1.779311]
# 580
# Iter 580. [Val Acc 62%, Loss 1.772615]
# 590
# Iter 590. [Val Acc 62%, Loss 1.763756]
# 0
# Iter 0. [Val Acc 60%, Loss 1.920582]
# 10
# Iter 10. [Val Acc 60%, Loss 1.902149]
# 20
# Iter 20. [Val Acc 60%, Loss 1.879234]
# 30
# Iter 30. [Val Acc 61%, Loss 1.859633]
# 40
# Iter 40. [Val Acc 61%, Loss 1.841994]
# 50
# Iter 50. [Val Acc 61%, Loss 1.822614]
# 60
# Iter 60. [Val Acc 61%, Loss 1.803076]
# 70
# Iter 70. [Val Acc 61%, Loss 1.783625]
# 80
# Iter 80. [Val Acc 61%, Loss 1.766440]
# 90
# Iter 90. [Val Acc 61%, Loss 1.751887]
# 100
# Iter 100. [Val Acc 62%, Loss 1.741428]
# 110
# Iter 110. [Val Acc 62%, Loss 1.728019]
# 120
# Iter 120. [Val Acc 62%, Loss 1.714452]
# 130
# Iter 130. [Val Acc 62%, Loss 1.698679]
# 140
# Iter 140. [Val Acc 62%, Loss 1.689521]
# 150
# Iter 150. [Val Acc 62%, Loss 1.675706]
# 160
# Iter 160. [Val Acc 63%, Loss 1.661474]
# 170
# Iter 170. [Val Acc 63%, Loss 1.651601]
# 180
# Iter 180. [Val Acc 64%, Loss 1.641710]
# 190
# Iter 190. [Val Acc 64%, Loss 1.629454]
# 200
# Iter 200. [Val Acc 64%, Loss 1.618763]
# 210
# Iter 210. [Val Acc 64%, Loss 1.606431]
# 220
# Iter 220. [Val Acc 65%, Loss 1.599294]
# 230
# Iter 230. [Val Acc 65%, Loss 1.591284]
# 240
# Iter 240. [Val Acc 66%, Loss 1.581215]
# 250
# Iter 250. [Val Acc 66%, Loss 1.572397]
# 260
# Iter 260. [Val Acc 66%, Loss 1.563673]
# 270
# Iter 270. [Val Acc 66%, Loss 1.554143]
# 280
# Iter 280. [Val Acc 66%, Loss 1.544458]
# 290
# Iter 290. [Val Acc 66%, Loss 1.533833]
# 300
# Iter 300. [Val Acc 67%, Loss 1.526621]
# 310
# Iter 310. [Val Acc 67%, Loss 1.517781]
# 320
# Iter 320. [Val Acc 67%, Loss 1.511479]
# 330
# Iter 330. [Val Acc 67%, Loss 1.509186]
# 340
# Iter 340. [Val Acc 67%, Loss 1.504556]
# 350
# Iter 350. [Val Acc 67%, Loss 1.489760]
# 360
# Iter 360. [Val Acc 68%, Loss 1.482721]
# 370
# Iter 370. [Val Acc 68%, Loss 1.472905]
# 380
# Iter 380. [Val Acc 68%, Loss 1.466676]
# 390
# Iter 390. [Val Acc 68%, Loss 1.460654]
# 400
# Iter 400. [Val Acc 68%, Loss 1.459424]
# 410
# Iter 410. [Val Acc 68%, Loss 1.452533]
# 420
# Iter 420. [Val Acc 68%, Loss 1.444549]
# 430
# Iter 430. [Val Acc 68%, Loss 1.440885]
# 440
# Iter 440. [Val Acc 68%, Loss 1.439104]
# 450
# Iter 450. [Val Acc 68%, Loss 1.431922]
# 460
# Iter 460. [Val Acc 68%, Loss 1.427749]
# 470
# Iter 470. [Val Acc 68%, Loss 1.424836]
# 480
# Iter 480. [Val Acc 68%, Loss 1.417762]
# 490
# Iter 490. [Val Acc 68%, Loss 1.413772]
# 500
# Iter 500. [Val Acc 68%, Loss 1.414609]
# 510
# Iter 510. [Val Acc 69%, Loss 1.411599]
# 520
# Iter 520. [Val Acc 69%, Loss 1.403285]
# 530
# Iter 530. [Val Acc 69%, Loss 1.400303]
# 540
# Iter 540. [Val Acc 69%, Loss 1.393605]
# 550
# Iter 550. [Val Acc 69%, Loss 1.389558]
# 560
# Iter 560. [Val Acc 69%, Loss 1.387133]
# 570
# Iter 570. [Val Acc 69%, Loss 1.385305]
# 580
# Iter 580. [Val Acc 69%, Loss 1.382621]
# 590
# Iter 590. [Val Acc 69%, Loss 1.382105]
# 0
# Iter 0. [Val Acc 66%, Loss 1.582457]
# 10
# Iter 10. [Val Acc 67%, Loss 1.557802]
# 20
# Iter 20. [Val Acc 68%, Loss 1.529111]
# 30
# Iter 30. [Val Acc 68%, Loss 1.500087]
# 40
# Iter 40. [Val Acc 69%, Loss 1.483410]
# 50
# Iter 50. [Val Acc 69%, Loss 1.474983]
# 60
# Iter 60. [Val Acc 70%, Loss 1.453020]
# 70
# Iter 70. [Val Acc 69%, Loss 1.436265]
# 80
# Iter 80. [Val Acc 69%, Loss 1.418183]
# 90
# Iter 90. [Val Acc 70%, Loss 1.409173]
# 100
# Iter 100. [Val Acc 70%, Loss 1.395377]
# 110
# Iter 110. [Val Acc 70%, Loss 1.384520]
# 120
# Iter 120. [Val Acc 69%, Loss 1.365699]
# 130
# Iter 130. [Val Acc 70%, Loss 1.351038]
# 140
# Iter 140. [Val Acc 70%, Loss 1.347411]
# 150
# Iter 150. [Val Acc 70%, Loss 1.341619]
# 160
# Iter 160. [Val Acc 70%, Loss 1.337359]
# 170
# Iter 170. [Val Acc 70%, Loss 1.337711]
# 180
# Iter 180. [Val Acc 70%, Loss 1.320349]
# 190
# Iter 190. [Val Acc 70%, Loss 1.320458]
# 200
# Iter 200. [Val Acc 70%, Loss 1.310891]
# 210
# Iter 210. [Val Acc 70%, Loss 1.299916]
# 220
# Iter 220. [Val Acc 71%, Loss 1.287958]
# 230
# Iter 230. [Val Acc 71%, Loss 1.273562]
# 240
# Iter 240. [Val Acc 71%, Loss 1.266063]
# 250
# Iter 250. [Val Acc 71%, Loss 1.262062]
# 260
# Iter 260. [Val Acc 71%, Loss 1.260355]
# 270
# Iter 270. [Val Acc 71%, Loss 1.252282]
# 280
# Iter 280. [Val Acc 71%, Loss 1.250934]
# 290
# Iter 290. [Val Acc 71%, Loss 1.247920]
# 300
# Iter 300. [Val Acc 71%, Loss 1.245479]
# 310
# Iter 310. [Val Acc 71%, Loss 1.237107]
# 320
# Iter 320. [Val Acc 71%, Loss 1.236602]
# 330
# Iter 330. [Val Acc 71%, Loss 1.236069]
# 340
# Iter 340. [Val Acc 71%, Loss 1.236452]
# 350
# Iter 350. [Val Acc 71%, Loss 1.231581]
# 360
# Iter 360. [Val Acc 71%, Loss 1.230684]
# 370
# Iter 370. [Val Acc 71%, Loss 1.219562]
# 380
# Iter 380. [Val Acc 71%, Loss 1.219435]
# 390
# Iter 390. [Val Acc 71%, Loss 1.215783]
# 400
# Iter 400. [Val Acc 71%, Loss 1.223217]
# 410
# Iter 410. [Val Acc 71%, Loss 1.218916]
# 420
# Iter 420. [Val Acc 70%, Loss 1.217884]
# 430
# Iter 430. [Val Acc 71%, Loss 1.215866]
# 440
# Iter 440. [Val Acc 71%, Loss 1.206702]
# 450
# Iter 450. [Val Acc 71%, Loss 1.210069]
# 460
# Iter 460. [Val Acc 71%, Loss 1.211149]
# 470
# Iter 470. [Val Acc 72%, Loss 1.206619]
# 480
# Iter 480. [Val Acc 72%, Loss 1.201180]
# 490
# Iter 490. [Val Acc 71%, Loss 1.204979]
# 500
# Iter 500. [Val Acc 72%, Loss 1.202071]
# 510
# Iter 510. [Val Acc 72%, Loss 1.200223]
# 520
# Iter 520. [Val Acc 72%, Loss 1.195718]
# 530
# Iter 530. [Val Acc 71%, Loss 1.195130]
# 540
# Iter 540. [Val Acc 71%, Loss 1.188328]
# 550
# Iter 550. [Val Acc 71%, Loss 1.178944]
# 560
# Iter 560. [Val Acc 71%, Loss 1.175745]
# 570
# Iter 570. [Val Acc 71%, Loss 1.180246]
# 580
# Iter 580. [Val Acc 71%, Loss 1.177770]
# 590
# Iter 590. [Val Acc 72%, Loss 1.170757]
# 0
# Iter 0. [Val Acc 67%, Loss 1.375671]
# 10
# Iter 10. [Val Acc 70%, Loss 1.326063]
# 20
# Iter 20. [Val Acc 71%, Loss 1.277937]
# 30
# Iter 30. [Val Acc 72%, Loss 1.257366]
# 40
# Iter 40. [Val Acc 72%, Loss 1.236816]
# 50
# Iter 50. [Val Acc 72%, Loss 1.223744]
# 60
# Iter 60. [Val Acc 72%, Loss 1.192069]
# 70
# Iter 70. [Val Acc 72%, Loss 1.179590]
# 80
# Iter 80. [Val Acc 72%, Loss 1.171530]
# 90
# Iter 90. [Val Acc 72%, Loss 1.160586]
# 100
# Iter 100. [Val Acc 72%, Loss 1.155996]
# 110
# Iter 110. [Val Acc 72%, Loss 1.160388]
# 120
# Iter 120. [Val Acc 72%, Loss 1.152296]
# 130
# Iter 130. [Val Acc 71%, Loss 1.153152]
# 140
# Iter 140. [Val Acc 72%, Loss 1.131197]
# 150
# Iter 150. [Val Acc 72%, Loss 1.138265]
# 160
# Iter 160. [Val Acc 72%, Loss 1.120918]
# 170
# Iter 170. [Val Acc 72%, Loss 1.117628]
# 180
# Iter 180. [Val Acc 72%, Loss 1.124596]
# 190
# Iter 190. [Val Acc 72%, Loss 1.137013]
# 200
# Iter 200. [Val Acc 72%, Loss 1.126838]
# 210
# Iter 210. [Val Acc 72%, Loss 1.126946]
# 220
# Iter 220. [Val Acc 72%, Loss 1.114067]
# 230
# Iter 230. [Val Acc 72%, Loss 1.102454]
# 240
# Iter 240. [Val Acc 73%, Loss 1.105213]
# 250
# Iter 250. [Val Acc 73%, Loss 1.121310]
# 260
# Iter 260. [Val Acc 72%, Loss 1.133353]
# 270
# Iter 270. [Val Acc 72%, Loss 1.120247]
# 280
# Iter 280. [Val Acc 72%, Loss 1.107152]
# 290
# Iter 290. [Val Acc 73%, Loss 1.111978]
# 300
# Iter 300. [Val Acc 72%, Loss 1.093766]
# 310
# Iter 310. [Val Acc 73%, Loss 1.113343]
# 320
# Iter 320. [Val Acc 73%, Loss 1.106641]
# 330
# Iter 330. [Val Acc 74%, Loss 1.104838]
# 340
# Iter 340. [Val Acc 73%, Loss 1.106620]
# 350
# Iter 350. [Val Acc 74%, Loss 1.104403]
# 360
# Iter 360. [Val Acc 74%, Loss 1.101046]
# 370
# Iter 370. [Val Acc 74%, Loss 1.103361]
# 380
# Iter 380. [Val Acc 74%, Loss 1.086902]
# 390
# Iter 390. [Val Acc 73%, Loss 1.109167]
# 400
# Iter 400. [Val Acc 74%, Loss 1.104378]
# 410
# Iter 410. [Val Acc 73%, Loss 1.082544]
# 420
# Iter 420. [Val Acc 74%, Loss 1.096754]
# 430
# Iter 430. [Val Acc 73%, Loss 1.090406]
# 440
# Iter 440. [Val Acc 74%, Loss 1.081477]
# 450
# Iter 450. [Val Acc 74%, Loss 1.075108]
# 460
# Iter 460. [Val Acc 74%, Loss 1.066480]
# 470
# Iter 470. [Val Acc 73%, Loss 1.085372]
# 480
# Iter 480. [Val Acc 74%, Loss 1.093524]
# 490
# Iter 490. [Val Acc 73%, Loss 1.086453]
# 500
# Iter 500. [Val Acc 73%, Loss 1.092754]
# 510
# Iter 510. [Val Acc 73%, Loss 1.083804]
# 520
# Iter 520. [Val Acc 73%, Loss 1.084915]
# 530
# Iter 530. [Val Acc 73%, Loss 1.074828]
# 540
# Iter 540. [Val Acc 74%, Loss 1.068251]
# 550
# Iter 550. [Val Acc 73%, Loss 1.081141]
# 560
# Iter 560. [Val Acc 73%, Loss 1.078180]
# 570
# Iter 570. [Val Acc 73%, Loss 1.071398]
# 580
# Iter 580. [Val Acc 72%, Loss 1.064231]
# 590
# Iter 590. [Val Acc 73%, Loss 1.065931]
# 0
# Iter 0. [Val Acc 67%, Loss 1.265482]
# 10
# Iter 10. [Val Acc 71%, Loss 1.166199]
# 20
# Iter 20. [Val Acc 72%, Loss 1.136001]
# 30
# Iter 30. [Val Acc 73%, Loss 1.101019]
# 40
# Iter 40. [Val Acc 73%, Loss 1.095456]
# 50
# Iter 50. [Val Acc 73%, Loss 1.102904]
# 60
# Iter 60. [Val Acc 73%, Loss 1.065857]
# 70
# Iter 70. [Val Acc 73%, Loss 1.085391]
# 80
# Iter 80. [Val Acc 74%, Loss 1.045834]
# 90
# Iter 90. [Val Acc 74%, Loss 1.068913]
# 100
# Iter 100. [Val Acc 73%, Loss 1.072847]
# 110
# Iter 110. [Val Acc 73%, Loss 1.070509]
# 120
# Iter 120. [Val Acc 73%, Loss 1.061700]
# 130
# Iter 130. [Val Acc 74%, Loss 1.059025]
# 140
# Iter 140. [Val Acc 74%, Loss 1.062902]
# 150
# Iter 150. [Val Acc 73%, Loss 1.066340]
# 160
# Iter 160. [Val Acc 75%, Loss 1.057391]
# 170
# Iter 170. [Val Acc 74%, Loss 1.065192]
# 180
# Iter 180. [Val Acc 74%, Loss 1.065882]
# 190
# Iter 190. [Val Acc 73%, Loss 1.061447]
# 200
# Iter 200. [Val Acc 73%, Loss 1.061833]
# 210
# Iter 210. [Val Acc 74%, Loss 1.064555]
# 220
# Iter 220. [Val Acc 73%, Loss 1.041398]
# 230
# Iter 230. [Val Acc 75%, Loss 1.053490]
# 240
# Iter 240. [Val Acc 74%, Loss 1.042839]
# 250
# Iter 250. [Val Acc 73%, Loss 1.057952]
# 260
# Iter 260. [Val Acc 74%, Loss 1.078703]
# 270
# Iter 270. [Val Acc 75%, Loss 1.075012]
# 280
# Iter 280. [Val Acc 73%, Loss 1.083986]
# 290
# Iter 290. [Val Acc 73%, Loss 1.084036]
# 300
# Iter 300. [Val Acc 73%, Loss 1.091914]
# 310
# Iter 310. [Val Acc 74%, Loss 1.073136]
# 320
# Iter 320. [Val Acc 73%, Loss 1.049062]
# 330
# Iter 330. [Val Acc 74%, Loss 1.074670]
# 340
# Iter 340. [Val Acc 74%, Loss 1.059006]
# 350
# Iter 350. [Val Acc 74%, Loss 1.057676]
# 360
# Iter 360. [Val Acc 74%, Loss 1.041978]
# 370
# Iter 370. [Val Acc 74%, Loss 1.045962]
# 380
# Iter 380. [Val Acc 73%, Loss 1.066887]
# 390
# Iter 390. [Val Acc 74%, Loss 1.073783]
# 400
# Iter 400. [Val Acc 73%, Loss 1.084956]
# 410
# Iter 410. [Val Acc 74%, Loss 1.061501]
# 420
# Iter 420. [Val Acc 74%, Loss 1.053629]
# 430
# Iter 430. [Val Acc 75%, Loss 1.049994]
# 440
# Iter 440. [Val Acc 75%, Loss 1.079939]
# 450
# Iter 450. [Val Acc 74%, Loss 1.064164]
# 460
# Iter 460. [Val Acc 74%, Loss 1.086837]
# 470
# Iter 470. [Val Acc 73%, Loss 1.075414]
# 480
# Iter 480. [Val Acc 75%, Loss 1.063765]
# 490
# Iter 490. [Val Acc 73%, Loss 1.067519]
# 500
# Iter 500. [Val Acc 76%, Loss 1.057647]
# 510
# Iter 510. [Val Acc 74%, Loss 1.052855]
# 520
# Iter 520. [Val Acc 73%, Loss 1.059727]
# 530
# Iter 530. [Val Acc 74%, Loss 1.054951]
# 540
# Iter 540. [Val Acc 73%, Loss 1.048789]
# 550
# Iter 550. [Val Acc 73%, Loss 1.093322]
# 560
# Iter 560. [Val Acc 73%, Loss 1.094756]
# 570
# Iter 570. [Val Acc 72%, Loss 1.055176]
# 580
# Iter 580. [Val Acc 72%, Loss 1.075534]
# 590
# Iter 590. [Val Acc 71%, Loss 1.069757]
# 0
# Iter 0. [Val Acc 66%, Loss 1.263905]
# 10
# Iter 10. [Val Acc 70%, Loss 1.108279]
# 20
# Iter 20. [Val Acc 72%, Loss 1.087804]
# 30
# Iter 30. [Val Acc 72%, Loss 1.110205]
# 40
# Iter 40. [Val Acc 72%, Loss 1.122590]
# 50
# Iter 50. [Val Acc 74%, Loss 1.083096]
# 60
# Iter 60. [Val Acc 73%, Loss 1.104781]
# 70
# Iter 70. [Val Acc 70%, Loss 1.099628]
# 80
# Iter 80. [Val Acc 74%, Loss 1.106017]
# 90
# Iter 90. [Val Acc 72%, Loss 1.087113]
# 100
# Iter 100. [Val Acc 72%, Loss 1.078955]
# 110
# Iter 110. [Val Acc 73%, Loss 1.081666]
# 120
# Iter 120. [Val Acc 74%, Loss 1.077740]
# 130
# Iter 130. [Val Acc 74%, Loss 1.085405]
# 140
# Iter 140. [Val Acc 70%, Loss 1.143135]
# 150
# Iter 150. [Val Acc 74%, Loss 1.066468]
# 160
# Iter 160. [Val Acc 73%, Loss 1.071175]
# 170
# Iter 170. [Val Acc 74%, Loss 1.063685]
# 180
# Iter 180. [Val Acc 74%, Loss 1.111638]
# 190
# Iter 190. [Val Acc 75%, Loss 1.109781]
# 200
# Iter 200. [Val Acc 74%, Loss 1.081952]
# 210
# Iter 210. [Val Acc 74%, Loss 1.107838]
# 220
# Iter 220. [Val Acc 71%, Loss 1.107132]
# 230
# Iter 230. [Val Acc 74%, Loss 1.110464]
# 240
# Iter 240. [Val Acc 74%, Loss 1.117796]
# 250
# Iter 250. [Val Acc 74%, Loss 1.064698]
# 260
# Iter 260. [Val Acc 72%, Loss 1.086433]
# 270
# Iter 270. [Val Acc 72%, Loss 1.100478]
# 280
# Iter 280. [Val Acc 72%, Loss 1.053805]
# 290
# Iter 290. [Val Acc 71%, Loss 1.060867]
# 300
# Iter 300. [Val Acc 74%, Loss 1.062758]
# 310
# Iter 310. [Val Acc 72%, Loss 1.047903]
# 320
# Iter 320. [Val Acc 72%, Loss 1.103312]
# 330
# Iter 330. [Val Acc 71%, Loss 1.097279]
# 340
# Iter 340. [Val Acc 74%, Loss 1.107981]
# 350
# Iter 350. [Val Acc 74%, Loss 1.091477]
# 360
# Iter 360. [Val Acc 73%, Loss 1.096049]
# 370
# Iter 370. [Val Acc 72%, Loss 1.055772]
# 380
# Iter 380. [Val Acc 71%, Loss 1.061321]
# 390
# Iter 390. [Val Acc 73%, Loss 1.080392]
# 400
# Iter 400. [Val Acc 74%, Loss 1.074454]
# 410
# Iter 410. [Val Acc 73%, Loss 1.098554]
# 420
# Iter 420. [Val Acc 73%, Loss 1.080902]
# 430
# Iter 430. [Val Acc 72%, Loss 1.089005]
# 440
# Iter 440. [Val Acc 73%, Loss 1.090991]
# 450
# Iter 450. [Val Acc 73%, Loss 1.117983]
# 460
# Iter 460. [Val Acc 73%, Loss 1.090063]
# 470
# Iter 470. [Val Acc 71%, Loss 1.116219]
# 480
# Iter 480. [Val Acc 71%, Loss 1.076674]
# 490
# Iter 490. [Val Acc 74%, Loss 1.058462]
# 500
# Iter 500. [Val Acc 73%, Loss 1.069420]
# 510
# Iter 510. [Val Acc 74%, Loss 1.063521]
# 520
# Iter 520. [Val Acc 73%, Loss 1.081304]
# 530
# Iter 530. [Val Acc 73%, Loss 1.086605]
# 540
# Iter 540. [Val Acc 76%, Loss 1.087411]
# 550
# Iter 550. [Val Acc 73%, Loss 1.106215]
# 560
# Iter 560. [Val Acc 74%, Loss 1.111605]
# 570
# Iter 570. [Val Acc 74%, Loss 1.140917]
# 580
# Iter 580. [Val Acc 73%, Loss 1.124683]
# 590
# Iter 590. [Val Acc 71%, Loss 1.137461]

# %% [markdown]
# **Explain and discuss your results here:**
#
# Finding the best μ value has been done by creating plots for accuracy with respect to epoch number, using different μ values in the range between the two values shown in part (f).
#
# This test has been done a few times and the ideal value seems to be between the numbers 0.03125 and 0.0625, where the convergence is still clear enough and the accuracy values get high and fast.

# %% [markdown]
# ### Part (h) -- 15%
#
# Using the values of `w` and `b` from part (g), compute your training accuracy, validation accuracy,
# and test accuracy. Are there any differences between those three values? If so, why?

# %%
#  Train the modelagain with the chosen mu
mu = 0.05
model, history_acc, history_cost = run_gradient_descent(train_norm_xs,train_ts,w0,b0,mu,batch_size=batch_size,max_iters=max_iters)

#plot learning curve  
plt.figure(1)
plt.plot(iters,history_acc)
plt.title(f'Accuracy vs. Number of epochs, mu = {mu}')

plt.figure(2)
plt.plot(iters,history_cost)
plt.title(f'cost vs. Number of epochs, mu = {mu}')

w,b = model
print(f'w = {w} \n\nb = {b}')
train_acc = get_accuracy(pred(w,b,train_norm_xs),train_ts)
val_acc = get_accuracy(pred(w,b,val_norm_xs),val_ts)
test_acc = get_accuracy(pred(w,b,test_norm_xs),test_ts)

print('train_acc = ', train_acc, ' val_acc = ', val_acc, ' test_acc = ', test_acc)
# Out:
# 0
# Iter 0. [Val Acc 66%, Loss 1.299850]
# 10
# Iter 10. [Val Acc 68%, Loss 1.265758]
# 20
# Iter 20. [Val Acc 70%, Loss 1.245977]
# 30
# Iter 30. [Val Acc 70%, Loss 1.215071]
# 40
# Iter 40. [Val Acc 71%, Loss 1.193566]
# 50
# Iter 50. [Val Acc 72%, Loss 1.179088]
# 60
# Iter 60. [Val Acc 72%, Loss 1.162744]
# 70
# Iter 70. [Val Acc 73%, Loss 1.149198]
# 80
# Iter 80. [Val Acc 73%, Loss 1.141292]
# 90
# Iter 90. [Val Acc 73%, Loss 1.129176]
# 100
# Iter 100. [Val Acc 73%, Loss 1.128165]
# 110
# Iter 110. [Val Acc 74%, Loss 1.118939]
# 120
# Iter 120. [Val Acc 74%, Loss 1.114946]
# 130
# Iter 130. [Val Acc 74%, Loss 1.104626]
# 140
# Iter 140. [Val Acc 75%, Loss 1.096910]
# 150
# Iter 150. [Val Acc 75%, Loss 1.091228]
# 160
# Iter 160. [Val Acc 75%, Loss 1.087473]
# 170
# Iter 170. [Val Acc 75%, Loss 1.081932]
# 180
# Iter 180. [Val Acc 74%, Loss 1.081723]
# 190
# Iter 190. [Val Acc 74%, Loss 1.076909]
# 200
# Iter 200. [Val Acc 74%, Loss 1.073839]
# 210
# Iter 210. [Val Acc 74%, Loss 1.076122]
# 220
# Iter 220. [Val Acc 74%, Loss 1.070819]
# 230
# Iter 230. [Val Acc 74%, Loss 1.070378]
# 240
# Iter 240. [Val Acc 74%, Loss 1.066576]
# 250
# Iter 250. [Val Acc 74%, Loss 1.062516]
# 260
# Iter 260. [Val Acc 74%, Loss 1.067158]
# 270
# Iter 270. [Val Acc 74%, Loss 1.063423]
# 280
# Iter 280. [Val Acc 74%, Loss 1.055778]
# 290
# Iter 290. [Val Acc 74%, Loss 1.055244]
# 300
# Iter 300. [Val Acc 74%, Loss 1.054330]
# 310
# Iter 310. [Val Acc 74%, Loss 1.051060]
# 320
# Iter 320. [Val Acc 74%, Loss 1.048198]
# 330
# Iter 330. [Val Acc 74%, Loss 1.046584]
# 340
# Iter 340. [Val Acc 74%, Loss 1.045709]
# 350
# Iter 350. [Val Acc 74%, Loss 1.045196]
# 360
# Iter 360. [Val Acc 74%, Loss 1.039938]
# 370
# Iter 370. [Val Acc 74%, Loss 1.042410]
# 380
# Iter 380. [Val Acc 74%, Loss 1.041278]
# 390
# Iter 390. [Val Acc 74%, Loss 1.039292]
# 400
# Iter 400. [Val Acc 74%, Loss 1.040866]
# 410
# Iter 410. [Val Acc 74%, Loss 1.046780]
# 420
# Iter 420. [Val Acc 74%, Loss 1.048724]
# 430
# Iter 430. [Val Acc 74%, Loss 1.038120]
# 440
# Iter 440. [Val Acc 74%, Loss 1.040263]
# 450
# Iter 450. [Val Acc 74%, Loss 1.036915]
# 460
# Iter 460. [Val Acc 75%, Loss 1.035452]
# 470
# Iter 470. [Val Acc 75%, Loss 1.032917]
# 480
# Iter 480. [Val Acc 75%, Loss 1.030206]
# 490
# Iter 490. [Val Acc 74%, Loss 1.032221]
# 500
# Iter 500. [Val Acc 74%, Loss 1.032515]
# 510
# Iter 510. [Val Acc 75%, Loss 1.036335]
# 520
# Iter 520. [Val Acc 75%, Loss 1.034990]
# 530
# Iter 530. [Val Acc 74%, Loss 1.032566]
# 540
# Iter 540. [Val Acc 74%, Loss 1.036134]
# 550
# Iter 550. [Val Acc 74%, Loss 1.035465]
# 560
# Iter 560. [Val Acc 74%, Loss 1.031890]
# 570
# Iter 570. [Val Acc 74%, Loss 1.037559]
# 580
# Iter 580. [Val Acc 75%, Loss 1.040442]
# 590
# Iter 590. [Val Acc 75%, Loss 1.045084]
# w = [ 1.40032832 -0.90905967 -0.24387441 -0.02568725 -0.09830757 -0.67561252
#  -0.04782788 -0.16844966 -0.16301709 -0.01912758 -0.28168068  0.09388838
#   0.24183686  0.19424061 -0.02633783  0.10678339  0.04356875  0.34057488
#   0.1558719   0.18972686  0.04611652  0.04495145  0.3755328   0.08962097
#  -0.12849354  0.0657595   0.17345353  0.01546188  0.0239914   0.0053927
#  -0.01290134 -0.03598721 -0.07991023  0.0367337  -0.00562499 -0.14675671
#  -0.03580475  0.12100797  0.11969519 -0.05514421 -0.10818762 -0.06138888
#   0.04085493  0.00142537  0.01855033  0.10667055  0.01361232 -0.10473391
#   0.00806137 -0.01053119 -0.0023778  -0.00618487  0.05400333 -0.0191361
#  -0.0879058   0.00883673 -0.13790697  0.07352023 -0.03041398 -0.00943278
#  -0.05686853 -0.02486598 -0.13501356  0.14624866 -0.12240195 -0.00966243
#   0.0056256   0.04229986 -0.08224232 -0.00820445 -0.05655194  0.00763745
#   0.05840059  0.07101731  0.05228368  0.09149347  0.00171705 -0.13337713
#  -0.03192941 -0.01759074 -0.03539586  0.01701439  0.00574542 -0.00836675
#   0.07767983 -0.00237701  0.08156455 -0.16968169 -0.04687515 -0.02084551]
#
# b = 0.309116054097137
# train_acc =  0.7324800889501226  val_acc =  0.73212  test_acc =  0.7269998063141584

# %% [markdown]
# **Explain and discuss your results here:**
#
# The accuracy is calculated using the same algorithm, and the same functions, though the inputs are different.
# The train accuracy represents the accuracy for the last chosen weights and biases, and the last iteration.
# The validation accuracy is using the same values but inputs out of the validation input set.
# The test accuracy is using a whole new set of inputs for the algorithm, and represents a second layer of validation to the model, intended to reveal overfitting if it may have happened.
#
# The difference between the values is small, and therefore we conclude that the model training  results are valid.

# %% [markdown]
# ### Part (i) -- 15%
#
# Writing a classifier like this is instructive, and helps you understand what happens when
# we train a model. However, in practice, we rarely write model building and training code
# from scratch. Instead, we typically use one of the well-tested libraries available in a package.
#
# Use `sklearn.linear_model.LogisticRegression` to build a linear classifier, and make predictions about the test set. Start by reading the
# [API documentation here](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html).
#
# Compute the training, validation and test accuracy of this model.

# %%
import sklearn.linear_model as lim

#config train model
model = lim.LogisticRegression(max_iter=100)
model.fit(train_norm_xs,train_ts)

#evaluate sk's model by pre-written functions
train_acc = model.score(train_norm_xs,train_ts)
val_acc = model.score(val_norm_xs,val_ts)
test_acc = model.score(test_norm_xs,test_ts)

print('train_acc = ', train_acc, ' val_acc = ', val_acc, ' test_acc = ', test_acc)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# train_acc =  0.733103706657965  val_acc =  0.73248  test_acc =  0.726748014720124

# %% [markdown]
# **This parts helps by checking if the code worked.**
# **Check if you get similar results, if not repair your code**
#
# The results are very similar, for all values.
